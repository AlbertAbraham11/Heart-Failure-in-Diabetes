# %%
import pandas as pd
import numpy as np

# %%
heart_clinical = pd.read_csv('heart_clinical.csv', encoding="Latin-1")

# %%
heart_clinical
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df = pd.DataFrame(heart_clinical)

# %%
print(df)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# My question is: Did the most diabetes patients are dying of heart failure or not?

# %%
filtered_df = df[(df["DEATH_EVENT"] == 1) ]
filtered_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 220  73.0        0                       582         0                 20
# 230  60.0        0                       166         0                 30
# 246  55.0        0                      2017         0                 25
# 262  65.0        1                       258         1                 25
# 266  55.0        0                      1199         0                 20
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
death_event_count = len(filtered_df)
death_event_count = filtered_df.shape[0]

print(f"Number of deaths: {death_event_count}")
# Out:
# Number of deaths: 96

# %% [markdown]
# Totally, 96 people died because of the heart failure.

# %%
filtered_df = df[(df["DEATH_EVENT"] == 1) & (df["diabetes"] == 1)]
filtered_df
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 4    65.000        1                       160         1                 20
# 7    60.000        1                       315         1                 60
# 19   48.000        1                       582         1                 55
# 21   65.000        1                       128         1                 30
# 24   75.000        0                       582         1                 30
# 25   80.000        0                       148         1                 38
# 27   70.000        0                       122         1                 45
# 29   82.000        0                        70         1                 30
# 30   94.000        0                       582         1                 38
# 32   50.000        1                       249         1                 35
# 34   65.000        0                        94         1                 50
# ...

# %%
death_event_count = len(filtered_df)
death_event_count = filtered_df.shape[0]

print(f"Number of deaths having diabetes: {death_event_count}")
# Out:
# Number of deaths having diabetes: 40

# %% [markdown]
# In 96 people 40 persons have died because of diabetes

# %%
filtered_df = df[(df["DEATH_EVENT"] == 1) & (df["high_blood_pressure"] == 1)]
filtered_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 5    90.0        1                        47         0                 40
# 9    80.0        1                       123         0                 35
# 10   75.0        1                        81         0                 38
# 11   62.0        0                       231         0                 25
# 13   50.0        1                       168         0                 38
# 18   70.0        1                       125         0                 25
# 21   65.0        1                       128         1                 30
# 22   68.0        1                       220         0                 35
# 24   75.0        0                       582         1                 30
# 26   95.0        1                       112         0                 40
# 27   70.0        0                       122         1                 45
# ...

# %%
death_event_count = len(filtered_df)
death_event_count = filtered_df.shape[0]

print(f"Number of deaths having high blood pressure: {death_event_count}")
# Out:
# Number of deaths having high blood pressure: 39

# %% [markdown]
# In 96 people, 39 people died because of high blood pressure

# %%
filtered_df = df[(df["DEATH_EVENT"] == 1) & (df["high_blood_pressure"] == 1) & (df["diabetes"] == 1) ]
filtered_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 21   65.0        1                       128         1                 30
# 24   75.0        0                       582         1                 30
# 27   70.0        0                       122         1                 45
# 30   94.0        0                       582         1                 38
# 32   50.0        1                       249         1                 35
# 34   65.0        0                        94         1                 50
# 37   82.0        1                       855         1                 50
# 41   50.0        0                       124         1                 30
# 42   70.0        0                       571         1                 45
# 47   60.0        0                       582         1                 38
# 53   70.0        1                        69         1                 50
# 59   72.0        0                       364         1                 20
# ...

# %%
death_event_count = len(filtered_df)
death_event_count = filtered_df.shape[0]

print(f"Number of deaths having high blood pressure as well as diabetes: {death_event_count}")
# Out:
# Number of deaths having high blood pressure as well as diabetes: 17

# %% [markdown]
# In 96 people 17 people died becuase of both high blood pressure as well as diabetes.
# Diabetes patients having high blood pressure will cause heart failure chances because the high blood pressure is the main cause of heart failure in people. So 17 people out of 40 people is died because of heart failure died because of heart failure.

# %%
import matplotlib.pyplot as plt

categories = ['Diabetic Patients Died', 'Diabetic Patients Not Died', 'Non-Diabetic Patients Died', 'Non-Diabetic Patients Not Died']
counts = [40, 54, 30, 78]

plt.figure(figsize=(10, 6))
plt.bar(categories, counts, color=['red', 'green', 'blue', 'purple'])

plt.title('Death of Patients by Diabetes Status')
plt.xlabel('Categories')
plt.ylabel('Counts')

plt.show()

# %%
import matplotlib.pyplot as plt

labels = 'Died of Diabetes Only', 'Died of High Blood Pressure Only', 'Died of Both Diabetes and High Blood Pressure'
sizes = [40, 30, 20]
colors = ['gold', 'yellowgreen', 'red']
explode = (0.1, 0, 0)  

plt.figure(figsize=(8, 9))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Cause of Death Distribution')
plt.axis('equal')  

plt.show()

# %% [markdown]
# The people died of diabetes as well as the high blood pressure is more as compared to the people died of only high blood pressure, because high blood pressure causes death to the heart patients.

# %%
filtered_df = df[(df["smoking"] == 1) & (df["diabetes"] == 1)]
filtered_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 7    60.0        1                       315         1                 60
# 25   80.0        0                       148         1                 38
# 27   70.0        0                       122         1                 45
# 29   82.0        0                        70         1                 30
# 41   50.0        0                       124         1                 30
# 42   70.0        0                       571         1                 45
# 45   50.0        0                       582         1                 38
# 47   60.0        0                       582         1                 38
# 54   60.0        1                       260         1                 38
# 59   72.0        0                       364         1                 20
# 71   58.0        0                       582         1                 35
# 73   65.0        0                       224         1                 50
# ...

# %%
death_event_count = len(filtered_df)
death_event_count = filtered_df.shape[0]

print(f"Number of patients having diabets and smoking: {death_event_count}")
# Out:
# Number of patients having diabets and smoking: 30

# %%
filtered_df = df[(df["ejection_fraction"] <= 30) & (df["diabetes"] == 1)]
filtered_df
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 4    65.000        1                       160         1                 20
# 21   65.000        1                       128         1                 30
# 24   75.000        0                       582         1                 30
# 29   82.000        0                        70         1                 30
# 33   50.000        1                       159         1                 30
# 38   60.000        0                      2656         1                 30
# 41   50.000        0                       124         1                 30
# 59   72.000        0                       364         1                 20
# 60   45.000        0                      7702         1                 25
# 66   42.000        1                       250         1                 15
# 69   65.000        0                       113         1                 25
# ...

# %%
death_event_count = len(filtered_df)
death_event_count = filtered_df.shape[0]

print(f"Number of patients having diabets and ejection fraction is less than 30: {death_event_count}")
# Out:
# Number of patients having diabets and ejection fraction is less than 30: 38

# %%
subset = df[['ejection_fraction', 'diabetes']]

subset = subset[subset['ejection_fraction'] < 30]

count_data = subset.groupby(['ejection_fraction', 'diabetes']).size().reset_index(name='count')

pivot_data = count_data.pivot(index='ejection_fraction', columns='diabetes', values='count')

pivot_data.plot(kind='bar', stacked=True)
plt.xlabel('Ejection Fraction')
plt.ylabel('Count')
plt.title('Comparison of Ejection Fraction < 30 with Diabetes')
plt.legend(title='Diabetes', labels=['No', 'Yes'])
plt.show()

# %%
filtered_df = df[ (df["diabetes"] == 0)]
filtered_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 5    90.0        1                        47         0                 40
# ..    ...      ...                       ...       ...                ...
# 289  90.0        1                       337         0                 38
# 291  60.0        0                       320         0                 35
# 295  55.0        0                      1820         0                 38
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
death_event_count = len(filtered_df)
death_event_count = filtered_df.shape[0]

print(f"Number of patients died not by diabetes: {death_event_count}")
# Out:
# Number of patients died not by diabetes: 174

# %%
filtered_df = df[ (df["diabetes"] == 1)]
filtered_df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 4    65.0        1                       160         1                 20
# 7    60.0        1                       315         1                 60
# 19   48.0        1                       582         1                 55
# 21   65.0        1                       128         1                 30
# 23   53.0        0                        63         1                 60
# ..    ...      ...                       ...       ...                ...
# 290  45.0        0                       615         1                 55
# 292  52.0        0                       190         1                 38
# 293  63.0        1                       103         1                 35
# 294  62.0        0                        61         1                 38
# 296  45.0        0                      2060         1                 60
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
death_event_count = len(filtered_df)
death_event_count = filtered_df.shape[0]

print(f"Number of patients died by diabetes: {death_event_count}")
# Out:
# Number of patients died by diabetes: 125

# %%
import matplotlib.pyplot as plt

categories = ['Smoking and Diabetes', 'Ejection Fraction < 30 and Diabetes', 'High Blood Pressure and Diabetes', 'Died not by Diabetes', 'Died by Diabetes']
counts = [30, 38, 17, 174, 125]

plt.figure(figsize=(9, 10))
plt.pie(counts, labels=categories, autopct='%1.1f%%', startangle=140, colors=['red','blue','yellow', 'green', 'grey'])

plt.title('Patient Conditions Distribution')

plt.axis('equal')
plt.show()

# %% [markdown]
# Smoking will cause high blood pressure and chance of heart failure in patients. So smoking diabetes patients would have the chance of heart failure.
# Ejection fraction less than 30 will have the high chance of getting heart failure, so ejection fraction having less than 30 in diabetes patients will have chance of heart failure.
# High blood pressure is the main thing that can cause heart failure, so diabetes patients with high blood pressure will have high chance of heart failure.
#
# So most of the diabetes patients have either high BP , less ejection fraction, or smokers. Therefore most of the diabetes patients have the chance of dying of heart failure.
